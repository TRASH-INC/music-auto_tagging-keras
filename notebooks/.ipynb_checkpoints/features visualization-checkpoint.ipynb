# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import numpy as np
import scipy as sp
import itertools
from functools import reduce
import seaborn as sns; sns.set()

# %%
features = pd.read_csv('../data/feature_dataframes/2019-03-21_11:28:18.csv')
features['track_name'] = features['track_name'].apply(lambda x: x[3:].split('.')[0])
del features['Unnamed: 0']
features.head()
# Out:
#            0          1          2          3    4         5           6  \
# 0  3014670.8  3226511.0  2437922.5  225743.28 -1.0      -1.0      -1.000
# 1  2270490.8  1333711.4  3528831.0  885750.30 -1.0      -1.0      -1.000
# 2  1658229.5  1107043.2   995609.8  827145.50 -1.0      -1.0      -1.000
# 3  1176145.8  1104262.1  1679923.2      -1.00 -1.0      -1.0   23781.238
# 4  1944218.4  1670096.4  1394698.6      -1.00 -1.0  133755.3  838256.900
#
#             7           8            9      ...              151       152  \
# 0   575931.70  223003.190    65127.336      ...        17.113045  4.806586
# 1  1074946.50      -1.000  1070559.400      ...        24.084652  5.944289
# 2   398089.94   30713.025   623992.060      ...         6.711153  3.625670
# 3   509908.60    6387.089    17066.305      ...        20.747921  5.119430
# 4   550950.90  397942.800       -1.000      ...        11.376924  4.278834
#
#         153        154        155       156       157        158        159  \
# 0 -0.067815  18.098577  17.894306 -0.985383  5.946620  12.635537  41.378174
# 1  0.267877  20.389080  23.899880 -0.974069  7.319490  10.237419  43.387790
# 2 -0.313312  12.432811  10.557815 -0.990510  3.698605  11.774317  28.647226
# 3  0.046033  18.750399  20.324224 -0.972095  5.617457  11.719130  32.148050
# 4 -0.171246  14.583193  13.398557 -0.989856  5.079335  11.464811  34.010260
#
#       track_name
# 0  In Bed Flying
# 1      Albatross
# 2         ITEYBC
# 3   Heist Huzzle
# 4  All The Night
#
# [5 rows x 161 columns]

# %%
tags_df = pd.read_csv('../data/Music_Genres_Moods_Tags.csv', header=0)
tags_df.head()
# Out:
#                                                     Song Name  \
# 0  0b7c952d-742a-4705-8ea0-0be5f90ce495               Origami
# 1  b475542d-d3f3-432b-b37c-a7d2e3646351       Columbus Circle
# 2  15ebd3d2-c1f1-4592-bf63-13d97804d759              Moonrise
# 3  e23f9615-58d4-4cf6-a2b2-01079117be22  Drummy Dubby Steps 2
# 4  9c4fcdec-afdf-4081-9ca8-d7df5d0caf63        Outside Circle
#
#                        Genre Genre ID    Mood/Category Mood/Category ID  \
# 0           Electronic/Synth        4    Upbeat, Chill            13, 1
# 1           Electronic/Synth        4    Chill, Groovy             1, 7
# 2                    Ambient        2     Dreamy, Slow            3, 11
# 3           Electronic/Synth        4  Weird/Eccentric               14
# 4  Hip-Hop, Electronic/Synth     6, 4            Chill                1
#
#                                              Tags  \
# 0  #percussion #house #perc #rhythmic #chillparty
# 1                  #dreamy #runway #house #trippy
# 2                     #dramatic #moving #touching
# 3                       #techno #drums #adventure
# 4                          #trap #smooth #driving
#
#      Epidemic Genre (if applicable) Epidemic Mood (If applicable)
# 0    Electronica & Dance:Deep House                Dreamy,Hopeful
# 1    Electronica & Dance:Deep House                  Epic,Chasing
# 2            Film:Mystery,Nostalgia             Floating,Peaceful
# 3         Electronica & Dance:Beats                    Mysterious
# 4  Hip Hop:Alternative Hip Hop,Trap                   Dark,Dreamy

# %%
data = features.merge(tags_df[['Song Name', 'Genre ID', 'Mood/Category ID']], left_on='track_name', right_on='Song Name')
labels = data[['Genre ID', 'Mood/Category ID']].apply(lambda x: x[0]+','+x[1], axis=1)
del data['Genre ID'], data['Mood/Category ID']
names = data['Song Name']
del data['Song Name'], data['track_name']
data.head()
# Out:
#            0          1          2          3    4         5           6  \
# 0  3014670.8  3226511.0  2437922.5  225743.28 -1.0      -1.0      -1.000
# 1  2270490.8  1333711.4  3528831.0  885750.30 -1.0      -1.0      -1.000
# 2  1658229.5  1107043.2   995609.8  827145.50 -1.0      -1.0      -1.000
# 3  1176145.8  1104262.1  1679923.2      -1.00 -1.0      -1.0   23781.238
# 4  1944218.4  1670096.4  1394698.6      -1.00 -1.0  133755.3  838256.900
#
#             7           8            9    ...            150        151  \
# 0   575931.70  223003.190    65127.336    ...      39.872700  17.113045
# 1  1074946.50      -1.000  1070559.400    ...      43.120804  24.084652
# 2   398089.94   30713.025   623992.060    ...      34.749737   6.711153
# 3   509908.60    6387.089    17066.305    ...      37.003994  20.747921
# 4   550950.90  397942.800       -1.000    ...      40.539820  11.376924
#
#         152       153        154        155       156       157        158  \
# 0  4.806586 -0.067815  18.098577  17.894306 -0.985383  5.946620  12.635537
# 1  5.944289  0.267877  20.389080  23.899880 -0.974069  7.319490  10.237419
# 2  3.625670 -0.313312  12.432811  10.557815 -0.990510  3.698605  11.774317
# 3  5.119430  0.046033  18.750399  20.324224 -0.972095  5.617457  11.719130
# 4  4.278834 -0.171246  14.583193  13.398557 -0.989856  5.079335  11.464811
#
#          159
# 0  41.378174
# 1  43.387790
# 2  28.647226
# 3  32.148050
# 4  34.010260
#
# [5 rows x 160 columns]

# %% [markdown]
# ## Cooccurence matrix of tags

# %%
tags = {
    1 : 'Chill',
    2: 'Dark',
    3: 'Dreamy',
    4: 'Eerie',
    5: 'Epic', 
    6: 'Funny',
    7: 'Groovy/Funk',
    8: 'Happy',
    9: 'Melancholy',
    10: 'Romantic/Sexy',
    11: 'Slow', 
    12: 'Suspense', 
    13: 'Upbeat', 
    14: 'Weird', 
    15: 'Acoustic',
    16: 'Ambient',
    17: 'Classical', 
    18: 'Electronic/Synth',
    19: 'Film Score', 
    20: 'Hip Hop/R&B', 
    21: 'Jazz',
    22: 'Latin',
    23: 'Pop',
    24: 'Rock',
    25: 'Soul'


}

# %%
permutations = reduce(lambda x, y: x+y, [list(itertools.permutations([int(y)-1 for y in x.split(',')], 2)) for x in labels ])
permutations = pd.DataFrame(permutations, columns=['left', 'right'])
permutations['count'] = 0
permutations.head()
# Out:
#    left  right  count
# 0     5      1      0
# 1     1      5      0
# 2     3     13      0
# 3     3     12      0
# 4    13      3      0

# %%
cooccurences = permutations.groupby(['left', 'right'])['count'].count().reset_index()
cooccurences.head()
# Out:
#    left  right  count
# 0     0      1      5
# 1     0      2      7
# 2     0      3      8
# 3     0      5     11
# 4     0      6      1

# %%
c_matrix = sp.sparse.csr_matrix((list(cooccurences['count']), (list(cooccurences['left']), cooccurences['right']))).todense()
fig, ax = plt.subplots(figsize=(80,80)) 
ax = sns.heatmap(c_matrix, ax=ax)
ax.tick_params(labelsize=40)
ax.set_xticklabels(labels=tags.values(), rotation=90)
ax.set_yticklabels(labels=tags.values(), rotation=0)
# Out:
# [Text(0, 0.5, 'Chill'),
#  Text(0, 1.5, 'Dark'),
#  Text(0, 2.5, 'Dreamy'),
#  Text(0, 3.5, 'Eerie'),
#  Text(0, 4.5, 'Epic'),
#  Text(0, 5.5, 'Funny'),
#  Text(0, 6.5, 'Groovy/Funk'),
#  Text(0, 7.5, 'Happy'),
#  Text(0, 8.5, 'Melancholy'),
#  Text(0, 9.5, 'Romantic/Sexy'),
#  Text(0, 10.5, 'Slow'),
#  Text(0, 11.5, 'Suspense'),
#  Text(0, 12.5, 'Upbeat'),
#  Text(0, 13.5, 'Weird')]

# %% [markdown]
# ## tSNE plots

# %%
def compute_mask(tag_id, serie):
    l = [[int(y) for y in x.split(',')] for x in serie ]
    res = [tag_id in x for x in l]
    return res

mask = compute_mask(4, labels)

# %%
def tSNE_plot(data, labels, tag_id, layer_id):
    
    
    # indices of the features for each layer
    idx_dict = {}
    for i in range(5):
        idx_dict[i+1] = [str(x) for x in list(range(32*i, 32*(i+1)))]
    
    mask = compute_mask(tag_id, labels)
    if layer_id not in idx_dict.keys():
        features_list = list(data.columns)
        title = 'tSNE with concatenated features from all the layers'
    else:
        features_list = idx_dict[layer_id]
        title = f'tSNE with features from layer {layer_id}'
    
    pca = PCA(n_components=30)
    pca_features = pca.fit_transform(data[features_list])
    
    tsne = TSNE(n_components=2, learning_rate=150, perplexity=30, angle=0.2, verbose=2).fit_transform(pca_features)
    tx, ty = tsne[:,0], tsne[:,1]
    tx = (tx-np.min(tx)) / (np.max(tx) - np.min(tx))
    ty = (ty-np.min(ty)) / (np.max(ty) - np.min(ty))
    
    plt.figure(figsize=(20,10))
    plt.scatter(tx[mask], ty[mask], color='g')
    plt.scatter(tx[[not x for x in mask]], ty[[not x for x in mask]], color='r')
    for i, name in enumerate(names):
        plt.annotate(name, (tx[i], ty[i]))
        
    plt.title(title)

# %%
tag_id = 2
for i in range(6):
    tSNE_plot(data, labels, tag_id, layer_id=i)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 95 samples in 0.000s...
# [t-SNE] Computed neighbors for 95 samples in 0.002s...
# [t-SNE] Computed conditional probabilities for sample 95 / 95
# [t-SNE] Mean sigma: 808133.288967
# [t-SNE] Computed conditional probabilities in 0.018s
# [t-SNE] Iteration 50: error = 55.3420868, gradient norm = 0.6476609 (50 iterations in 0.024s)
# [t-SNE] Iteration 100: error = 54.1272011, gradient norm = 0.6388079 (50 iterations in 0.024s)
# [t-SNE] Iteration 150: error = 59.1272507, gradient norm = 0.5917329 (50 iterations in 0.019s)
# [t-SNE] Iteration 200: error = 54.9719582, gradient norm = 0.6137551 (50 iterations in 0.015s)
# [t-SNE] Iteration 250: error = 56.6467400, gradient norm = 0.6235434 (50 iterations in 0.015s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 56.646740
# [t-SNE] Iteration 300: error = 0.9565452, gradient norm = 0.0106568 (50 iterations in 0.014s)
# [t-SNE] Iteration 350: error = 0.6056291, gradient norm = 0.0105801 (50 iterations in 0.014s)
# [t-SNE] Iteration 400: error = 0.5073361, gradient norm = 0.0027508 (50 iterations in 0.014s)
# [t-SNE] Iteration 450: error = 0.4613571, gradient norm = 0.0012264 (50 iterations in 0.014s)
# [t-SNE] Iteration 500: error = 0.4375699, gradient norm = 0.0035940 (50 iterations in 0.014s)
# [t-SNE] Iteration 550: error = 0.3721101, gradient norm = 0.0037325 (50 iterations in 0.015s)
# [t-SNE] Iteration 600: error = 0.3428607, gradient norm = 0.0029898 (50 iterations in 0.015s)
# [t-SNE] Iteration 650: error = 0.3215414, gradient norm = 0.0046165 (50 iterations in 0.014s)
# [t-SNE] Iteration 700: error = 0.2969948, gradient norm = 0.0006399 (50 iterations in 0.014s)
# [t-SNE] Iteration 750: error = 0.2968684, gradient norm = 0.0001289 (50 iterations in 0.014s)
# [t-SNE] Iteration 800: error = 0.2968679, gradient norm = 0.0000669 (50 iterations in 0.014s)
# [t-SNE] Iteration 850: error = 0.2968671, gradient norm = 0.0000271 (50 iterations in 0.014s)
# [t-SNE] Iteration 900: error = 0.2968676, gradient norm = 0.0000582 (50 iterations in 0.014s)
# [t-SNE] Iteration 950: error = 0.2969238, gradient norm = 0.0020751 (50 iterations in 0.014s)
# [t-SNE] Iteration 1000: error = 0.2968692, gradient norm = 0.0002778 (50 iterations in 0.014s)
# [t-SNE] KL divergence after 1000 iterations: 0.296869
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 95 samples in 0.000s...
# [t-SNE] Computed neighbors for 95 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 95 / 95
# [t-SNE] Mean sigma: 898035.593985
# [t-SNE] Computed conditional probabilities in 0.009s
# [t-SNE] Iteration 50: error = 56.2558746, gradient norm = 0.6477408 (50 iterations in 0.015s)
# [t-SNE] Iteration 100: error = 57.5085182, gradient norm = 0.5049723 (50 iterations in 0.015s)
# [t-SNE] Iteration 150: error = 56.6753654, gradient norm = 0.5433843 (50 iterations in 0.015s)
# [t-SNE] Iteration 200: error = 56.8439827, gradient norm = 0.5995145 (50 iterations in 0.016s)
# [t-SNE] Iteration 250: error = 56.2743950, gradient norm = 0.6785483 (50 iterations in 0.015s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 56.274395
# [t-SNE] Iteration 300: error = 0.8041260, gradient norm = 0.0062923 (50 iterations in 0.015s)
# [t-SNE] Iteration 350: error = 0.4203505, gradient norm = 0.0086153 (50 iterations in 0.014s)
# [t-SNE] Iteration 400: error = 0.3468219, gradient norm = 0.0028666 (50 iterations in 0.014s)
# [t-SNE] Iteration 450: error = 0.3220463, gradient norm = 0.0031756 (50 iterations in 0.014s)
# [t-SNE] Iteration 500: error = 0.3138478, gradient norm = 0.0005942 (50 iterations in 0.014s)
# [t-SNE] Iteration 550: error = 0.3138324, gradient norm = 0.0003522 (50 iterations in 0.014s)
# [t-SNE] Iteration 600: error = 0.3138421, gradient norm = 0.0001556 (50 iterations in 0.013s)
# [t-SNE] Iteration 650: error = 0.3138431, gradient norm = 0.0002676 (50 iterations in 0.013s)
# [t-SNE] Iteration 700: error = 0.3138485, gradient norm = 0.0001662 (50 iterations in 0.013s)
# [t-SNE] Iteration 750: error = 0.3138490, gradient norm = 0.0002009 (50 iterations in 0.013s)
# [t-SNE] Iteration 800: error = 0.3138491, gradient norm = 0.0000931 (50 iterations in 0.014s)
# [t-SNE] Iteration 850: error = 0.3138476, gradient norm = 0.0001831 (50 iterations in 0.013s)
# [t-SNE] Iteration 900: error = 0.3138479, gradient norm = 0.0001122 (50 iterations in 0.014s)
# [t-SNE] Iteration 900: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 900 iterations: 0.313848
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 95 samples in 0.000s...
# [t-SNE] Computed neighbors for 95 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 95 / 95
# [t-SNE] Mean sigma: 98937.138184
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 53.4194794, gradient norm = 0.6531367 (50 iterations in 0.015s)
# [t-SNE] Iteration 100: error = 53.6401329, gradient norm = 0.5715394 (50 iterations in 0.015s)
# [t-SNE] Iteration 150: error = 52.7785721, gradient norm = 0.5962260 (50 iterations in 0.015s)
# [t-SNE] Iteration 200: error = 53.8752022, gradient norm = 0.5940671 (50 iterations in 0.015s)
# [t-SNE] Iteration 250: error = 55.1526260, gradient norm = 0.5671551 (50 iterations in 0.015s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 55.152626
# [t-SNE] Iteration 300: error = 0.4555158, gradient norm = 0.0117894 (50 iterations in 0.014s)
# [t-SNE] Iteration 350: error = 0.3255314, gradient norm = 0.0034599 (50 iterations in 0.014s)
# [t-SNE] Iteration 400: error = 0.2885559, gradient norm = 0.0046531 (50 iterations in 0.014s)
# [t-SNE] Iteration 450: error = 0.2279646, gradient norm = 0.0009786 (50 iterations in 0.015s)
# [t-SNE] Iteration 500: error = 0.2278804, gradient norm = 0.0000271 (50 iterations in 0.014s)
# [t-SNE] Iteration 550: error = 0.2278809, gradient norm = 0.0000087 (50 iterations in 0.014s)
# [t-SNE] Iteration 600: error = 0.2278778, gradient norm = 0.0000204 (50 iterations in 0.014s)
# [t-SNE] Iteration 650: error = 0.2278772, gradient norm = 0.0000171 (50 iterations in 0.014s)
# [t-SNE] Iteration 700: error = 0.2278677, gradient norm = 0.0000136 (50 iterations in 0.014s)
# [t-SNE] Iteration 750: error = 0.2278786, gradient norm = 0.0000291 (50 iterations in 0.014s)
# [t-SNE] Iteration 800: error = 0.2278677, gradient norm = 0.0000118 (50 iterations in 0.014s)
# [t-SNE] Iteration 850: error = 0.2278618, gradient norm = 0.0000048 (50 iterations in 0.014s)
# [t-SNE] Iteration 900: error = 0.2278675, gradient norm = 0.0000083 (50 iterations in 0.014s)
# [t-SNE] Iteration 950: error = 0.2278700, gradient norm = 0.0000102 (50 iterations in 0.014s)
# [t-SNE] Iteration 1000: error = 0.2278915, gradient norm = 0.0000213 (50 iterations in 0.014s)
# [t-SNE] KL divergence after 1000 iterations: 0.227892
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 95 samples in 0.000s...
# [t-SNE] Computed neighbors for 95 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 95 / 95
# [t-SNE] Mean sigma: 5253.972021
# [t-SNE] Computed conditional probabilities in 0.007s
# [t-SNE] Iteration 50: error = 53.7857857, gradient norm = 0.6517774 (50 iterations in 0.015s)
# [t-SNE] Iteration 100: error = 54.0725327, gradient norm = 0.5681406 (50 iterations in 0.015s)
# [t-SNE] Iteration 150: error = 52.1648331, gradient norm = 0.6874719 (50 iterations in 0.015s)
# [t-SNE] Iteration 200: error = 51.6833878, gradient norm = 0.6716831 (50 iterations in 0.015s)
# [t-SNE] Iteration 250: error = 52.7129440, gradient norm = 0.6345907 (50 iterations in 0.015s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 52.712944
# [t-SNE] Iteration 300: error = 0.5068113, gradient norm = 0.0051453 (50 iterations in 0.015s)
# [t-SNE] Iteration 350: error = 0.2955247, gradient norm = 0.0023509 (50 iterations in 0.015s)
# [t-SNE] Iteration 400: error = 0.2546833, gradient norm = 0.0035307 (50 iterations in 0.014s)
# [t-SNE] Iteration 450: error = 0.2532401, gradient norm = 0.0000680 (50 iterations in 0.013s)
# [t-SNE] Iteration 500: error = 0.2532278, gradient norm = 0.0000297 (50 iterations in 0.013s)
# [t-SNE] Iteration 550: error = 0.2532265, gradient norm = 0.0000396 (50 iterations in 0.013s)
# [t-SNE] Iteration 600: error = 0.2532270, gradient norm = 0.0000360 (50 iterations in 0.013s)
# [t-SNE] Iteration 650: error = 0.2532275, gradient norm = 0.0000308 (50 iterations in 0.013s)
# [t-SNE] Iteration 700: error = 0.2532275, gradient norm = 0.0000340 (50 iterations in 0.013s)
# [t-SNE] Iteration 750: error = 0.2532274, gradient norm = 0.0000279 (50 iterations in 0.013s)
# [t-SNE] Iteration 800: error = 0.2532282, gradient norm = 0.0000384 (50 iterations in 0.013s)
# [t-SNE] Iteration 850: error = 0.2532277, gradient norm = 0.0000329 (50 iterations in 0.013s)
# [t-SNE] Iteration 900: error = 0.2532281, gradient norm = 0.0000224 (50 iterations in 0.013s)
# [t-SNE] Iteration 900: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 900 iterations: 0.253228
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 95 samples in 0.000s...
# [t-SNE] Computed neighbors for 95 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 95 / 95
# [t-SNE] Mean sigma: 104.664382
# [t-SNE] Computed conditional probabilities in 0.006s
# [t-SNE] Iteration 50: error = 54.5391273, gradient norm = 0.6927017 (50 iterations in 0.015s)
# [t-SNE] Iteration 100: error = 55.1845665, gradient norm = 0.5980942 (50 iterations in 0.015s)
# [t-SNE] Iteration 150: error = 56.0033302, gradient norm = 0.5495647 (50 iterations in 0.016s)
# [t-SNE] Iteration 200: error = 55.3364143, gradient norm = 0.6151865 (50 iterations in 0.015s)
# [t-SNE] Iteration 250: error = 60.4358940, gradient norm = 0.5796562 (50 iterations in 0.016s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 60.435894
# [t-SNE] Iteration 300: error = 0.9846320, gradient norm = 0.0050772 (50 iterations in 0.015s)
# [t-SNE] Iteration 350: error = 0.5658545, gradient norm = 0.0070684 (50 iterations in 0.014s)
# [t-SNE] Iteration 400: error = 0.3791252, gradient norm = 0.0066517 (50 iterations in 0.014s)
# [t-SNE] Iteration 450: error = 0.3768862, gradient norm = 0.0183344 (50 iterations in 0.015s)
# [t-SNE] Iteration 500: error = 0.3598516, gradient norm = 0.0022222 (50 iterations in 0.014s)
# [t-SNE] Iteration 550: error = 0.3565558, gradient norm = 0.0003628 (50 iterations in 0.014s)
# [t-SNE] Iteration 600: error = 0.3521473, gradient norm = 0.0010675 (50 iterations in 0.014s)
# [t-SNE] Iteration 650: error = 0.3464559, gradient norm = 0.0031619 (50 iterations in 0.014s)
# [t-SNE] Iteration 700: error = 0.3424924, gradient norm = 0.0038408 (50 iterations in 0.014s)
# [t-SNE] Iteration 750: error = 0.3359933, gradient norm = 0.0158538 (50 iterations in 0.014s)
# [t-SNE] Iteration 800: error = 0.3593488, gradient norm = 0.0246060 (50 iterations in 0.014s)
# [t-SNE] Iteration 850: error = 0.3950604, gradient norm = 0.0122614 (50 iterations in 0.014s)
# [t-SNE] Iteration 900: error = 0.3724124, gradient norm = 0.0179977 (50 iterations in 0.015s)
# [t-SNE] Iteration 950: error = 0.3317382, gradient norm = 0.0287034 (50 iterations in 0.014s)
# [t-SNE] Iteration 1000: error = 0.3602228, gradient norm = 0.0210419 (50 iterations in 0.014s)
# [t-SNE] KL divergence after 1000 iterations: 0.360223
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 95 samples in 0.000s...
# [t-SNE] Computed neighbors for 95 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 95 / 95
# [t-SNE] Mean sigma: 20.925682
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = 53.9502869, gradient norm = 0.6357578 (50 iterations in 0.015s)
# [t-SNE] Iteration 100: error = 55.1045990, gradient norm = 0.5917196 (50 iterations in 0.015s)
# [t-SNE] Iteration 150: error = 54.3516273, gradient norm = 0.6175669 (50 iterations in 0.015s)
# [t-SNE] Iteration 200: error = 53.0554733, gradient norm = 0.5806729 (50 iterations in 0.015s)
# [t-SNE] Iteration 250: error = 55.8634796, gradient norm = 0.5859032 (50 iterations in 0.015s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 55.863480
# [t-SNE] Iteration 300: error = 0.4514058, gradient norm = 0.0062218 (50 iterations in 0.015s)
# [t-SNE] Iteration 350: error = 0.3504386, gradient norm = 0.0023722 (50 iterations in 0.014s)
# [t-SNE] Iteration 400: error = 0.2984656, gradient norm = 0.0025201 (50 iterations in 0.014s)
# [t-SNE] Iteration 450: error = 0.2495766, gradient norm = 0.0021739 (50 iterations in 0.014s)
# [t-SNE] Iteration 500: error = 0.2288826, gradient norm = 0.0004392 (50 iterations in 0.015s)
# [t-SNE] Iteration 550: error = 0.2287899, gradient norm = 0.0000090 (50 iterations in 0.014s)
# [t-SNE] Iteration 600: error = 0.2287925, gradient norm = 0.0000083 (50 iterations in 0.014s)
# [t-SNE] Iteration 650: error = 0.2287936, gradient norm = 0.0000168 (50 iterations in 0.014s)
# [t-SNE] Iteration 700: error = 0.2287938, gradient norm = 0.0000067 (50 iterations in 0.014s)
# [t-SNE] Iteration 750: error = 0.2287939, gradient norm = 0.0000062 (50 iterations in 0.014s)
# [t-SNE] Iteration 800: error = 0.2287939, gradient norm = 0.0000083 (50 iterations in 0.014s)
# [t-SNE] Iteration 850: error = 0.2287941, gradient norm = 0.0000122 (50 iterations in 0.014s)
# [t-SNE] Iteration 900: error = 0.2287941, gradient norm = 0.0000070 (50 iterations in 0.014s)
# [t-SNE] Iteration 900: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 900 iterations: 0.228794

# %%
# Out:
# 133
